# %% [markdown]
# 1. What is Object-Oriented Programming (OOP) ?
#
#  ▶ Object-oriented programming(OOP) is a style of programming characterized by the identification of classes of objects closely linked with the objects closely linked with the methods(functions) with which they are associated. It also includes ideas of inheritance of attributes and methods.
#
# 2. What is a class in OOPS ?
#
#  ▶ In object-oriented programming, a class is a blueprint for creating objects(a particular data structure),providing intial values for state(member variables or attributes), and implementations of behavior(member functions or methods). The user-defined objects are created using the class keyword.
#
# 3. What is an object in OOPs ?
#
#  ▶ An object is an instance of a class that encapsulates data and functionality including that data. Objects serve as the basic building blocks of OOP applications, embodying both the properties (data) and behaviors (methods) relevant to the software being developed.
#
# 4. What is the difference between abstraction and encapsulation ?
#
#  ▶ Abstraction in python simplifies complex systems, hiding implementations details for better code redability. Encapsulation safeguards data integrity by restricting direct access to an object's data and methods.
#
# 5. What are dunder methods in Python ?
#
#  ▶ Dunder methods are special methods in python. They start and end with double underscores (hence the name)--like __init__,__str__,__len__ and __getitem__.They allow your custom objects to behave like built-in types.
#
# 6. Explain the concept of inheritance in OOPS ?
#
#  ▶ Inheritance allows programmers to create classes that are built upon existing classes, to specify a new implementation while maintaining the same behaviors(realizing an interface), to reuse code and to independently extend original software via public classes and interfaces.
#
# 7. What is polymorphism in OOPS ?
#
#  ▶ Polymorphism is one of the most important concepts in OOP. It describes the ability of something to have or to displayed in more than one form. The different forms arise because these entities can be assigned different meanings and used in various ways in multiple contexts.
#
# 8. How is encapsulation achieved in Python ?
#
#  ▶ Encapsulation is achieved by declaring a class's data members and methods as either private or protected. But in python, we do not have keywords like public,private and protected,as in case of java. Instead, we achieve this by using single and double underscores.
#
# 9. What is a constructor in Python ?
#
#  ▶ In python, a constructor is a special method called when an object is created. Its purpose is to assign values to the data members within the class when an object is intialized.
#
# 10. What are class and static methods in Python ?
#
#  ▶ A class method can access or modify the class state while a static method can't access or modify it. In general, static methods know nothing about the class state. They are utility-type methods that take some parameters that take some parameters and work upon those parameters. On the other hand class methods must have class as a parameter.
#
# 11. What is method overloading in Python ?
#
#  ▶ The concept of method overloading in python refers to the ability to define multiple methods of the same name, but with different parameters. In many object-oriented programming languages, overloading is used to create different implementations of a method, depending on the number or type of arguments passed.
#
# 12. What is method overriding in OOP ?
#
#  ▶ Method overriding in object-oriented programming, is a language feauture that allows a subclass or child class to provide a specific implementation of a method that is already provided by one of its superclasses or parent classes.
#
# 13.  What is a property decorator in Python ?
#
#  ▶ A decorator is a design pattern in python that allows a user to add new functionality to an existing object without modifying its structure. Decorators are typically applied to functions, and they play a crucial role in enhancing or modifying the behavior of functions.
#
# 14. Why is polymorphism important in OOPS ?
#
#  ▶ Polymorphism is a core principle in OOPS and used in various aspects of software development. It promotes code reuse, flexibility and extensibility by allowing objects of different classes to be treated as object of a common superclass or interface.
#
# 15. What is an abstract class in Python ?
#
#  ▶ In python, an abstract class is a class that cannot be instantiated on its own and is meant to be subclassed by other classes. Abstract classes are created using abc(Abstract Base Classes) module.
#
# 16. What are the advantages of OOPS ?
#
#  ▶ Advantages of OOPS:-
#
#  1. We can build the programs from standard working modules that communicate with one another, rather than having to start writing code from scratch which leads to saving of development time and higher productivity.
#
#  2. OOPS language allows to break the program into the bit-sized promblems that can be solved easily(one object at a time).
#
#  3. The new technology promises greater programmer productivity, better quality of software and lesser maintenance cost.
#
#  4. It is possible that multiple instances of object co-exist without any interference.
#
#  5. OOPS systems can be easily upgraded from small to large systems
#
# 17. What is the difference between a class variable and an instance variable ?
#
#  ▶ Instance variable:-
#
#     1. They declared without using keyword 'static'.
#
#     2. Each object of the class gets its own copy of instance variables.
#
#     3. They can be accessed only through the object of the class.
#
#   ▶ Class variable:-
#
#     1. They are declared using keyword 'static'
#
#     2. All the objects of a class share of same copy of class variables.
#
#     3. They can be accessed using the class name or object.
#
# 18. What is multiple inheritance in Python ?
#
#  ▶ Multiple inheritances are when a child class is derived from two or more parent classes. For example, you are inheriting some of the features from your father and some from your mother. In this case, we have to write the names of both parent classes inside the brackets of the child class.
#
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python ?
#
#  ▶ __str__ is used for informal string representations, such as printing objects for user consumption. __repr__ is used for formal string representations, including debugging, logging and object inspection.
#
# 20. What is the significance of the ‘super()’ function in Python ?
#
#  ▶ In python, super() is a builtin function that allows access to methods and properties of a parent or superclass from a child or subclass.
#
# 21.  What is the significance of the __del__ method in Python ?
#
#  ▶ The __del__ method in python is a powerful tool for managing resource cleanup when objects are destroyed. It allows you to define specific actions that should be taken when an object is garbage collected, such as closing files, releasing locks, or closing network connections.
#
# 22. What is the difference between @staticmethod and @classmethod in Python ?
#
#  ▶ Class method Vs Static method
#
#     1. A class method takes cls as the first parameter while a static method needs no specific parameters.
#
#     2. A class method can access or modify the class state while a static method can't access or modify it.
#
#     3. In general. static methods know nothing about the class state. They are utility type methods that take some parameters and work upon those parameters. On the other hand class methods must have class as a paramete.
#
#     4. We use @classmethod decorator in python to create a class method and we use @staticmethod decorator to create a static method in python.
#
# 23. How does polymorphism work in Python with inheritance ?
#
#  ▶ Polymorphism in python, specifically when used with inheritance, enables objects of different classes to respond to the same method call in a way that is specific to thier class.This is achieved through method overriding , where a subclass provide its own implementation of a method that is already defined in its parent class.
#
#  For Example:-

# %%
class Animal:
  def speak(self):
    return "generic animal sound"
class Dog(Animal):
  def speak(self):
    return "woof! woof!"
class Cat(Animal):
  def speak(meow):
    return "meow!"

cat=Cat()
cat.speak()
# Out:
# 'meow!'

# %% [markdown]
# 24. What is method chaining in Python OOP ?
#
#  ▶Method chaining in python is a programming technique used in object oriented programming where multiple methods are called sequentially on the same object. This is achieved by having each method return the object itself(specifically,self),allowing subsequent methods to be called directly on result of the previous method call. It enhances code readability and conciseness by eliminating the need for intermediate variables.
#
#  Example:-

# %%
class Calculator:
  def __init__(self,value=0):
    self.value=value
  def add(self,num):
    self.value+=num
    return self
  def substract(self,num):
    self.value-=num
    return self
  def multiply(self,num):
    self.value*=num
    return self
  def get_value(self):
    return self.value

calc=Calculator(20)
calc.add(45).get_value()
# Out:
# 65

# %% [markdown]
# 25. What is the purpose of the __call__ method in Python ?
#
#  ▶ The __call__ method is part of python built-in methods also called dunder or magic methods because have two prefixes and suffix underscores in the method name. The main idea of __call__method is to write a class and involve it like a function. You can refer to it as callable object.

# %% [markdown]
# Practical Questions:-
#
# 1.  1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

# %%
class Animal:
  def speak(self):
    print("This is sound of a generic animal")
class Dog(Animal):
  def speak(self):
    print("Bark!")

# %%
dog=Animal()
dog.speak()
# Out:
# This is sound of a generic animal

# %% [markdown]
# 2.  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

# %%
from abc import ABC,abstractmethod
import math

class Shape(ABC):
  @abstractmethod
  def area(self):
   pass

class Circle(Shape):
  def __init__(self,radius):
    self.radius=radius
  def area(self):
    return math.pi*self.radius**2

class Rectangle(Shape):
  def __init__(self,length,breadth):
    self.length=length
    self.breadth=breadth
  def area(self):
    return self.length*self.breadth

# %%
rect=Rectangle(5,6)
rect.area()
# Out:
# 30

# %% [markdown]
# 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
  def __init__(self,vehicle_type):
    self.type=vehicle_type
class Car(Vehicle):
  def __init__(self,vehicle_type,brand):
    super().__init__(vehicle_type)
    self.brand=brand
class ElectricCar(Car):
  def __init__(self,vehicle_type,brand,battery_capacity):
    super().__init__(vehicle_type,brand)
    self.battery=battery_capacity

  def display_info(self):
    print(f"Type:{self.type}")
    print(f"Brand:{self.brand}")
    print(f"Battery:{self.battery} KWh")

# %%
e_car=ElectricCar("Electric car","Tesla",75)
e_car.display_info()
# Out:
# Type:Electric car
# Brand:Tesla
# Battery:75 KWh

# %% [markdown]
# 4.  Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

# %%
class Bird:
  def fly(self):
    print("Birds can fly")
class Sparrow(Bird):
  def fly(self):
    print("sparrow can fly")
class Penguin(Bird):
  def fly(self):
    print("penguins can't fly")

# %%
p=Penguin()
p.fly()
# Out:
# penguins can't fly

# %% [markdown]
# 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
  def __init__(self,owner,bank_balance=0):
    self.owner=owner
    self.__balance=bank_balance #private attribute

  def Deposit(self,amount):
    self.__balance+=amount
    return f"deposited : {self.__balance}"
  def withdraw(self,amount):
    if amount<=self.__balance:
      self.__balance-=amount
      print(f"withdrew: {amount}")
    else:
      return "insufficient funds"
  def check_balance(self):
    return f"available balance : {self.__balance}"

# %%
c1=BankAccount("shubham")
c1.Deposit(5000)
# Out:
# 'deposited : 5000'

# %%
c1.withdraw(5100)
# Out:
# 'insufficient funds'

# %%
c1.withdraw(500)
# Out:
# withdrew: 500

# %%
c1.check_balance()
# Out:
# 'available balance : 4500'

# %% [markdown]
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play()..

# %%
class Instrument:
  def play(self):
    print("playing an instrument")
class Guitar:
  def play(self):
    print("strumming a guitar")
class Piano:
  def play(self):
    print("playing the piano")

def perform(Instrument):
  Instrument.play()

# %%
piano=Piano()
perform(piano)
# Out:
# playing the piano

# %% [markdown]
# 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
  @classmethod
  def add_numbers(cls,x,y):
    return x+y
  @staticmethod
  def substract_numbers(x,y):
    return x-y


sum_result = MathOperations.add_numbers(10, 5)
print(f"sum: {sum_result}")

diff_result = MathOperations.substract_numbers(10,5)
print(f"difference: {diff_result}")
# Out:
# sum: 15
# difference: 5

# %% [markdown]
# 8. Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
  count = 0
  def __init__(self,name):
    self.name = name
    Person.count+=1
  @classmethod
  def get_person_count(cls):
    return cls.count

# %%
p1=Person("mukesh")
p2=Person("shanti")
p3=Person("golu")
p4=Person("ramu")

Person.get_person_count()
# Out:
# 4

# %% [markdown]
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

# %%
class Fraction:
  def __init__(self, numerator, denominator):
    self.numerator = numerator
    self.denominator = denominator

  def __str__(self):
    return f"{self.numerator}/{self.denominator}"

# %%
f1=Fraction(6,10)
f2=Fraction(10,17)
print(f1)
print(f2)
# Out:
# 6/10
# 10/17

# %% [markdown]
# 10.  Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.

# %%
class Vector:
  def __init__(self,x,y):
    self.x=x
    self.y=y

  def __add__(self,other):
    return Vector(self.x+other.x,self.y+other.y)

  def __str__(self):
    return f"Vector({self.x},{self.y})"

v1=Vector(4,5)
v2=Vector(8,12)
v3=v1+v2

print(v1)
print(v2)
print(v3)
# Out:
# Vector(4,5)
# Vector(8,12)
# Vector(12,17)

# %% [markdown]
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

# %%
class Person:
  def __init__(self,name,age):
    self.name=name
    self.age=age
  def greet(self):
    return f"hello my name is {self.name} and I am {self.age} years old"

# %%
p1=Person("Shubham",23)
p1.greet()
# Out:
# 'hello my name is Shubham and I am 23 years old'

# %% [markdown]
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

# %%
class Student:
  def __init__(self,name,grades):
    self.name=name
    self.grades=grades
  def average_grade(self):
    if not self.grades:
      return 0
    else:
      return sum(self.grades)/len(self.grades)

# %%
s1=Student("david",[55,84,93,34,78])
s1.average_grade()
# Out:
# 68.8

# %% [markdown]
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

# %%
class Rectangle:
  def __init__(self):
    self.length=0
    self.width=0
  def set_dimensions(self,length,width):
    self.length = length
    self.width = width
  def area(self):
    return self.length*self.width

# %%
rect1=Rectangle()
rect1.set_dimensions(7,8)
rect1.area()
# Out:
# 56

# %% [markdown]
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
  def __init__(self,name,hours_worked,hourly_rate):
    self.name=name
    self.hours_worked=hours_worked
    self.hourly_rate=hourly_rate
  def calculate_salary(self):
    return self.hours_worked*self.hourly_rate
class Manager(Employee):
  def __init__(self,name,hours_worked,hourly_rate,bonus):
    super().__init__(name,hours_worked,hourly_rate)
    self.bonus=bonus
  def calculate_salary(self):
    base_salary=super().calculate_salary()
    return base_salary+self.bonus

# %%
m1=Manager("alice",78,40,2000)
m1.calculate_salary()
# Out:
# 5120

# %%
e1=Employee("bob",40,25)
e1.calculate_salary()
# Out:
# 1000

# %% [markdown]
# 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.

# %%
class Product:
  def __init__(self,name,price,quantity):
    self.name=name
    self.price=price
    self.quantity=quantity
  def display_info(self):
    print(f"product name is {self.name}")
    print(f"price of a product {self.price}")
    print(f"quantity of a product {self.quantity}")
  def total_price(self):
    return self.price*self.quantity

# %%
p1=Product("Dettol soap",40,24)
p1.display_info()
# Out:
# product name is Dettol soap
# price of a product 40
# quantity of a product 24

# %%
p1.total_price()
# Out:
# 960

# %% [markdown]
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

# %%
from abc import ABC,abstractmethod

class Animal(ABC):
  @abstractmethod
  def sound(self):
    return
class Cow(Animal):
  def sound(self):
    return "sound of a cow"
class Sheep(Animal):
  def sound(self):
    return "sound of a sheep"

# %%
cow=Cow()
cow.sound()
# Out:
# 'sound of a cow'

# %%
sheep=Sheep()
sheep.sound()
# Out:
# 'sound of a sheep'

# %% [markdown]
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

# %%
class Book:
  def __init__(self,title,author,year_published):
    self.title=title
    self.author=author
    self.year_published=year_published
  def get_book_info(self):
    print(f"'{self.title}' by {self.author} published in {self.year_published}")

# %%
b1=Book("silent patient","alex michaelides",2019)
b1.get_book_info()
# Out:
# 'silent patient' by alex michaelides published in 2019

# %% [markdown]
#  18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

# %%
class House:
  def __init__(self,address,price):
    self.address=address
    self.price=price
  def details(self):
    print(f"Address is {self.address} and price is {self.price}")
class Mansion(House):
  def __init__(self,address,price,no_of_rooms):
   super().__init__(address,price)
   self.no_of_rooms=no_of_rooms
  def details(self):
    super().details()
    print(f"It has {self.no_of_rooms} rooms.")

# %%
h1=House("271 ring road",500000)
h1.details()
# Out:
# Address is 271 ring road and price is 500000

# %%
m1=Mansion("271 ring road",500000,12)
m1.details()
# Out:
# Address is 271 ring road and price is 500000
# It has 12 rooms.
